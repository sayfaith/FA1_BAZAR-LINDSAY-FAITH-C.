# %%
import requests

# URL of the raw dataset file on GitHub
url = 

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Save the content of the response to a file
    with open('words.txt', 'wb') as f:
        f.write(response.content)
        print('Dataset saved to file.')
else:
    print('Failed to download dataset.')

# Total number of words
with open('words.txt', 'r') as f:
    count = sum(1 for line in f)
    print("Total number of words:", count)

# Longest word
with open('words.txt', 'r') as f:
    longest_word = ''
    for line in f:
        word = line.strip()
        if len(word) > len(longest_word):
            longest_word = word
    print("Longest word:", longest_word)

# Number of words that start with a certain letter (use user input)
letter = input("Enter a letter: ")
with open('words.txt', 'r') as f:
    count = sum(1 for line in f if line.startswith(letter))
    print("Number of words that start with", letter + ":", count)

# All the words that contain a certain substring (use user input)
substring = input("Enter a substring: ")
with open('words.txt', 'r') as f:
    words = [line.strip() for line in f if substring in line]
    print("Words that contain", substring + ":", words)

# All the words that are palindromes
with open('words.txt', 'r') as f:
    palindromes = [line.strip() for line in f if line.strip() == line.strip()[::-1]]
    print("Palindromes:", palindromes)

# Frequency of each letter
letter_counts = {}
with open('words.txt', 'r') as f:
    for line in f:
        word = line.strip()
        for letter in word:
            if letter in letter_counts:
                letter_counts[letter] += 1
            else:
                letter_counts[letter] = 1
    print("Letter counts:", letter_counts)
# Out:
# Dataset saved to file.
# Total number of words: 113783
# Longest word: counterdemonstrations
# Enter a letter: c
# Number of words that start with c: 10383
# Enter a substring: w
# Words that contain w: ['aardwolf', 'aardwolves', 'abwatt', 'abwatts', 'acknowledge', 'acknowledged', 'acknowledgement', 'acknowledgements', 'acknowledges', 'acknowledging', 'acknowledgment', 'acknowledgments', 'adown', 'advowson', 'advowsons', 'afterward', 'afterwards', 'agalwood', 'agalwoods', 'aglow', 'agueweed', 'agueweeds', 'aircrew', 'aircrews', 'airflow', 'airflows', 'airglow', 'airglows', 'airscrew', 'airscrews', 'airward', 'airwave', 'airwaves', 'airway', 'airways', 'airwise', 'airwoman', 'airwomen', 'ajowan', 'ajowans', 'alewife', 'alewives', 'alleyway', 'alleyways', 'allow', 'allowable', 'allowance', 'allowances', 'allowed', 'allowing', 'allows', 'alow', 'alway', 'always', 'anew', 'angleworm', 'angleworms', 'answer', 'answerable', 'answered', 'answerer', 'answerers', 'answering', 'answers', 'antiwar', 'antiwhite', 'antiwiretapping', 'antiwoman', 'anyhow', 'anyway', 'anyways', 'anywhere', 'anywheres', 'anywise', 'archway', 'archways', 'areaway', 'areaways', 'armyworm', 'armyworms', 'arrow', 'arrowed', 'arrowhead', 'arrowheads', 'arrowing', 'arrows', 'arrowy', 'artwork', 'artworks', 'askew', 'assemblywoman', 'assemblywomen', 'asswage', 'asswaged', 'asswages', 'asswaging', 'aswarm', 'aswirl', 'aswoon', 'athwart', 'atwain', 'atween', 'atwitter', 'avow', 'avowable', 'avowably', 'avowal', 'avowals', 'avowed', 'avowedly', 'avower', 'avowers', 'avowing', 'avows', 'aw', 'awa', 'await', 'awaited', 'awaiter', 'awaiters', 'awaiting', 'awaits', 'awake', 'awaked', 'awaken', 'awakened', 'awakener', 'awakeners', 'awakening', 'awakens', 'awakes', 'awaking', 'award', 'awarded', 'awardee', 'awardees', 'awarder', 'awarders', 'awarding', 'awards', 'aware', 'awash', 'away', 'awayness', 'awaynesses', 'awe', 'aweary', 'aweather', 'awed', 'awee', 'aweigh', 'aweing', 'aweless', 'awes', 'awesome', 'awesomely', 'awful', 'awfuller', 'awfullest', 'awfully', 'awhile', 'awhirl', 'awing', 'awkward', 'awkwarder', 'awkwardest', 'awkwardly', 'awkwardness', 'awkwardnesses', 'awl', 'awless', 'awls', 'awlwort', 'awlworts', 'awmous', 'awn', 'awned', 'awning', 'awninged', 'awnings', 'awnless', 'awns', 'awny', 'awoke', 'awoken', 'awol', 'awols', 'awry', 'backarrow', 'backarrows', 'backsaw', 'backsaws', 'backward', 'backwardness', 'backwardnesses', 'backwards', 'backwash', 'backwashed', 'backwashes', 'backwashing', 'backwood', 'backwoods', 'bagwig', 'bagwigs', 'bagworm', 'bagworms', 'bailiwick', 'bailiwicks', 'baklawa', 'baklawas', 'bandwagon', 'bandwagons', 'bandwidth', 'bandwidths', 'barbwire', 'barbwires', 'barlow', 'barlows', 'barrow', 'barrows', 'bartholomew', 'barware', 'barwares', 'bashaw', 'bashaws', 'basswood', 'basswoods', 'batfowl', 'batfowled', 'batfowling', 'batfowls', 'batwing', 'bawbee', 'bawbees', 'bawcock', 'bawcocks', 'bawd', 'bawdier', 'bawdies', 'bawdiest', 'bawdily', 'bawdiness', 'bawdinesses', 'bawdric', 'bawdrics', 'bawdries', 'bawdry', 'bawds', 'bawdy', 'bawl', 'bawled', 'bawler', 'bawlers', 'bawling', 'bawls', 'bawsunt', 'bawtie', 'bawties', 'bawty', 'baywood', 'baywoods', 'beadwork', 'beadworks', 'beclown', 'beclowned', 'beclowning', 'beclowns', 'becoward', 'becowarded', 'becowarding', 'becowards', 'becrawl', 'becrawled', 'becrawling', 'becrawls', 'becrowd', 'becrowded', 'becrowding', 'becrowds', 'bedew', 'bedewed', 'bedewing', 'bedews', 'bedgown', 'bedgowns', 'bedstraw', 'bedstraws', 'bedward', 'bedwards', 'bedwarf', 'bedwarfed', 'bedwarfing', 'bedwarfs', 'beefwood', 'beefwoods', 'beeswax', 'beeswaxes', 'beeswing', 'beeswings', 'beflower', 'beflowered', 'beflowering', 'beflowers', 'behowl', 'behowled', 'behowling', 'behowls', 'bejewel', 'bejeweled', 'bejeweling', 'bejewelled', 'bejewelling', 'bejewels', 'bellow', 'bellowed', 'bellower', 'bellowers', 'bellowing', 'bellows', 'bellwether', 'bellwethers', 'bellwort', 'bellworts', 'below', 'belows', 'beltway', 'beltways', 'bendways', 'bendwise', 'bentwood', 'bentwoods', 'beshadow', 'beshadowed', 'beshadowing', 'beshadows', 'beshrew', 'beshrewed', 'beshrewing', 'beshrews', 'besnow', 'besn ...
# Palindromes: ['aa', 'aba', 'aga', 'aha', 'ala', 'alula', 'ama', 'ana', 'anna', 'ava', 'awa', 'bib', 'bob', 'boob', 'bub', 'civic', 'dad', 'deed', 'deified', 'deked', 'deled', 'denned', 'dewed', 'did', 'dud', 'eke', 'eme', 'ere', 'eve', 'ewe', 'eye', 'gag', 'gig', 'hah', 'halalah', 'hallah', 'huh', 'kaiak', 'kayak', 'keek', 'kook', 'level', 'madam', 'marram', 'mem', 'mim', 'minim', 'mom', 'mum', 'noon', 'nun', 'oho', 'otto', 'pap', 'peep', 'pep', 'pip', 'poop', 'pop', 'pup', 'radar', 'redder', 'refer', 'reifier', 'repaper', 'reviver', 'rotator', 'rotor', 'sagas', 'sees', 'selles', 'sememes', 'semes', 'seres', 'sexes', 'shahs', 'sis', 'solos', 'sos', 'stets', 'tat', 'tenet', 'terret', 'tit', 'toot', 'tot', 'tut', 'vav', 'waw', 'wow', 'yay']
# Letter counts: {'a': 68574, 'h': 20186, 'e': 106752, 'd': 34548, 'i': 77392, 'n': 60505, 'g': 27832, 's': 86526, 'l': 47003, 'r': 64963, 'v': 9186, 'k': 9366, 'w': 8533, 'o': 54538, 'f': 12706, 'b': 17794, 'c': 34281, 'u': 31151, 't': 57029, 'm': 24739, 'p': 25789, 'y': 13473, 'x': 2700, 'j': 1780, 'z': 3750, 'q': 1632}
